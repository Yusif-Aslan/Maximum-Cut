# %% [raw]
# # Cell 1: imports
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import wilcoxon, friedmanchisquare
#
# # Optional: make plots a bit prettier
# plt.rcParams["figure.figsize"] = (8, 5)
# plt.rcParams["axes.grid"] = True
